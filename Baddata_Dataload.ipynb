# %%
from pyspark.sql.types import IntegerType, StringType, StructType, StructField

schema = StructType([
    StructField("_c0", IntegerType(), True),
    StructField("_c1", StringType(), True),
    StructField("_c2", StringType(), True),
    StructField("_corrupt_record", StringType(), True)
])

# %%
df = spark.read.format("csv").option('header',"false") \
               .schema(schema) \
               .option('mode',"PERMISSIVE") \
               .option("columnNameCorruptRecord","_corrupt_record") \
               .load("/Volumes/batch4/class/inputfiles/baddata.csv")

display(df)

# %%
df1 = df.filter("_corrupt_record IS NULL") \
        .drop("_corrupt_record")

display(df1)

# %%
# %sql
select * from batch4.class.circuits
where CircuitID is not null

# %%
df1 = df.filter("_corrupt_record IS NOT NULL")

display(df1)

# %%
df = spark.read.format("csv").option('header',"false") \
               .option('mode',"DROPMALFORMED") \
               .load("/Volumes/batch4/class/inputfiles/baddata.csv")

display(df)

# %%
df = spark.read.format("csv").option('header',"false") \
               .option('mode',"FAILFAST") \
               .load("/Volumes/batch4/class/inputfiles/baddata.csv")

display(df)
