# %%
# %run ../includes/config

# %%
# %pip install openpyxl

# %%
dbutils.library.restartPython()

# %%
import pandas as pd

# %%
excel_file = pd.ExcelFile("/Volumes/batch4/class/inputfiles/250227 - OFFICIAL (from AB) Item & Distributor Master for Pabst.xlsx", engine='openpyxl')

sheetname = excel_file.sheet_names

print(sheetname)

# %%
pdf = pd.read_excel("/Volumes/batch4/class/inputfiles/250227 - OFFICIAL (from AB) Item & Distributor Master for Pabst.xlsx", sheet_name=sheetname[1], engine='openpyxl')

df = spark.createDataFrame(pdf)

display(df)
